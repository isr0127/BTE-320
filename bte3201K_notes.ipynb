# %% [markdown]
# <a href="https://colab.research.google.com/github/isr0127/BTE-320/blob/main/bte3201K_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
1x = 2
# Out:
#   File "/tmp/ipython-input-2079796758.py", line 1
#     1x = 2
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# This is a test

# %%
interest = 3 # Interest rate (absolute value %)
principal = 3000
n = 1 # one year interest

final = principal * (1 + interest/100) ** n

print (final)
# Out:
# 3090.0

# %%
interst = 3 # interest rate (absolute vallue %)
principal = 3000
n = 1 # one year interest

final = principal * (1 + interest/100) ** n

print (final)
# Out:
# 3090.0

# %%
print(interest, principal)
print(final)
# Out:
# 3 3000
# 3090.0

# %%
1"\n"
# Out:
#   File "/tmp/ipython-input-3108897497.py", line 1
#     1"\n"
#      ^
# SyntaxError: invalid syntax

# %%
print("Interest rate:", interest, sep="=>")
print("Number of years:", n)
# Out:
# Interest rate:=>3
# Number of years: 1

# %%
print("Interest rate:", interest, end="---")
print("Number of years:", n, sep=" ")
# Out:
# Interest rate: 3---Number of years:1

# %%
print("Interest rate:", interest, sep=">>>", end="$$$")
print("Number of years:", n)
# Out:
# Interest rate:>>>3$$$Number of years: 1

# %%
print("Interest rate:", interest, "; Number of years", n)
# Out:
# Interest rate: 3 ; Number of years 1

# %%
'''python
"......{}...{}...".format(a,b)
# Out:
#   File "/tmp/ipython-input-1673406908.py", line 1
#     '''python
#     ^
# SyntaxError: incomplete input

# %%
("Interest rate: {}; Number of years: {}". format(interest, n))
# Out:
# 'Interest rate: 3; Number of years: 1'

# %%
f".......{a}.....{b}"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2296235114.py in <cell line: 0>()
# ----> 1 f".......{a}.....{b}"
#
# NameError: name 'a' is not defined

# %%
print(f"Interest rate: {interest}; Number of years: {n}")
# Out:
# Interest rate: 3; Number of years: 1

# %%
interest = input("Enter interest value (%): ")
print(interest)
# Out:
# Enter interest value (%): 3
# 3

# %%
if condition:
  exprs

# %%
email = "URGENT!!! Click on the link: www.phis.org and receive a reward!"
has_urgent = "URGENT"

if has_urgent in email:
  print("Phising!")
# Out:
# Phising!
